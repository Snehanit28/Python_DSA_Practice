# %% [markdown]
# # What is programming language? #
# Programming language is a formal language that provides instruction for a computer to execute.
#
# - There are two types of programming language ->
# 1. High Level language
# 2. Low Levet language
#
# > A computer or mechine can under stand only binary numbers (0,1)
#
# # High level language #
# High Level language is the laguage writen by humans , Mechine couldn't understand high level laguage directly.We convert the high level language to the low level lanuage by whhich computer can understand it.(Python,Java,c,c++ are the high level lanuage)
#
# # Low level language #
# Low Level laguage is that language which understand by computer directly.
#
# # Compiler and Interprator #
# We use Compiler or Interprator to convert the high level language to low level language.
#
# + Compiler converts hole code at once.
#
# + Interprator converts hole code line by line.
#
# > python use interprator

# %% [markdown]
# # Python #
# python is a  high level , versetile , general purpose programming laguage designed for readability and easy for use.
#
# + Interprated
# + High level
# + Object oriented
# + Extensive libraries
# + Begginer friendly

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 34
b = 45
avg = (a + b) / 2
print(avg)
# Out:
# 39.5
