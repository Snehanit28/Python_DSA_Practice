# %% [markdown]
# # Space Complexity #
# Space complexity refers the amount of memory an algorithm uses as a function of the input size. It's measure of how much memory an algorithm requires to execute and solve the problem.
